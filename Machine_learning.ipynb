# %% [markdown]
# <a href="https://colab.research.google.com/github/raitig/Python/blob/main/Machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df=pd.read_csv('/content/StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.figure(figsize=(6, 4))
sns.histplot(df["math score"], bins=20, kde=True, color="#ff69b4")
plt.title("Distribution of Math Scores")
plt.tight_layout()
plt.show()

# %%
moderate_math_students = df[(df['math score'] >= 60) & (df['math score'] <= 80)]


total_moderate_math = moderate_math_students.shape[0]

print("Total moderate math students:", total_moderate_math)
# Out:
# Total moderate math students: 501

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)

df = pd.read_csv("StudentsPerformance.csv")

filtered_df = df[(df["math score"] >= 60) & (df["math score"] <= 75)]

plt.figure(figsize=(8, 5))
sns.histplot(filtered_df["math score"], bins=15, kde=True, color="#69b3a2")
plt.title("Math Scores Between 60 and 75")
plt.xlabel("Math Score")
plt.ylabel("Number of Students")
plt.tight_layout()
plt.show()

# %%
min_math_score = filtered_df['math score'].min()
print("Minimum math score between 60 and 75:", min_math_score)
# Out:
# Minimum math score between 60 and 75: 60

# %%
moderate_math_students = df[(df['math score'] >= 60) & (df['math score'] < 65)]


total_moderate_math = moderate_math_students.shape[0]

print("Total moderate math students:", total_moderate_math)
# Out:
# Total moderate math students: 124

# %%
moderate_math_students = df[(df['math score'] >= 65) & (df['math score'] < 70)]


total_moderate_math = moderate_math_students.shape[0]

print("Total moderate math students:", total_moderate_math)
# Out:
# Total moderate math students: 144

# %%
moderate_math_students = df[(df['math score'] >= 70) & (df['math score'] < 75)]


total_moderate_math = moderate_math_students.shape[0]

print("Total moderate math students:", total_moderate_math)
# Out:
# Total moderate math students: 114

# %%
moderate_math_students = df[(df['math score'] >= 75) & (df['math score'] <= 80)]


total_moderate_math = moderate_math_students.shape[0]

print("Total moderate math students:", total_moderate_math)
# Out:
# Total moderate math students: 119

# %%
moderate_math_students_60_65 = df[(df['math score'] >= 60) & (df['math score'] < 65)]
display(moderate_math_students[['gender', 'race/ethnicity']])
# Out:
#      gender race/ethnicity
# 8      male        group D
# 29   female        group D
# 31   female        group B
# 62     male        group A
# 67   female        group C
# ..      ...            ...
# 976    male        group B
# 977    male        group C
# 993  female        group D
# 994    male        group A
# 996    male        group C
#
# [124 rows x 2 columns]

# %%
moderate_math_students_= df[(df['math score'] >= 65) & (df['math score'] < 70)]
display(moderate_math_students[['gender', 'race/ethnicity']])
# Out:
#      gender race/ethnicity
# 4      male        group C
# 13     male        group A
# 38   female        group D
# 51     male        group E
# 60     male        group E
# ..      ...            ...
# 969  female        group B
# 971    male        group C
# 982    male        group B
# 983  female        group A
# 999  female        group D
#
# [102 rows x 2 columns]

# %%
moderate_math_students = df[(df['math score'] >= 70) & (df['math score'] < 75)]
display(moderate_math_students[['gender', 'race/ethnicity']])
# Out:
#      gender race/ethnicity
# 0    female        group B
# 5    female        group B
# 24     male        group D
# 25     male        group A
# 28     male        group C
# ..      ...            ...
# 940    male        group C
# 952  female        group E
# 955    male        group E
# 964    male        group D
# 984  female        group C
#
# [114 rows x 2 columns]

# %%
moderate_math_students = df[(df['math score'] >= 75) & (df['math score'] < 80)]
display(moderate_math_students[['gender', 'race/ethnicity']])
# Out:
#      gender race/ethnicity
# 4      male        group C
# 13     male        group A
# 38   female        group D
# 51     male        group E
# 60     male        group E
# ..      ...            ...
# 969  female        group B
# 971    male        group C
# 982    male        group B
# 983  female        group A
# 999  female        group D
#
# [102 rows x 2 columns]

# %%
gender_count = moderate_math_students_60_65['gender'].value_counts()
display(gender_count)
# Out:
# gender
# female    83
# male      61
# Name: count, dtype: int64
